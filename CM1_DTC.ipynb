.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ,
       0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ]


cm1_de_dtc= [0.15 , 0.1469697 , 0.14545455, 0.14393939, 0.13484848, 0.13333333, 0.13333333, 0.13181818, 0.13030303, 0.12727273, 0.12424242, 0.12424242, 0.12424242, 0.12424242, 0.12272727, 0.12272727, 0.12121212, 0.12121212, 0.12121212, 0.11969697, 0.11969697, 0.11969697, 0.11969697, 0.11818182, 0.11818182, 0.11818182, 0.11666667, 0.10909091, 0.10909091, 0.10909091, 0.10909091, 0.10909091, 0.10909091, 0.10909091, 0.10909091, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10757576, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10606061, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.10454545, 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 , 0.1030303 ]

cm1_pso_dtc= [0.1530303 , 0.14848485, 0.14545455, 0.14242424, 0.14242424, 0.13484848, 0.13333333, 0.13181818, 0.13181818, 0.13181818, 0.13181818, 0.13181818, 0.13181818, 0.13181818, 0.13181818, 0.13181818, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.13030303, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273, 0.12727273]

cm1_wso_dtc = [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.15151515151515152, 0.15151515151515152, 0.13636363636363635, 0.13636363636363635, 0.12121212121212122, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606, 0.10606060606060606]

# %%
import pickle

file = open('test.pkl','wb')

pickle.dump(cm1_ga_dtc, file)
pickle.dump(cm1_aco_dtc, file)
pickle.dump(cm1_de_dtc, file)
pickle.dump(cm1_pso_dtc, file)
pickle.dump(cm1_wso_dtc, file)

file.close()

# %%
import matplotlib.pyplot as plt
  
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(8)

plt.title("Fitness for CM1 Dataset - DT Classifier")
plt.xlabel('No. of Iterations')
plt.ylabel('Fitness Value (Error)')

# plot lines
plt.plot(cm1_ga_dtc, label = "FSGA", linewidth=3)
plt.plot(cm1_aco_dtc, label = "FSACO", linewidth=3)
plt.plot(cm1_pso_dtc, label= "FSPSO", linewidth=3)
plt.plot(cm1_de_dtc, label= "FSDE", linewidth=3)
plt.plot(cm1_wso_dtc, label= "FSGJO", linewidth=3)
plt.legend(fontsize="15")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.grid()
plt.show()

# %%
f.savefig('CM1_DT.png', format='png', dpi=1000, bbox_inches='tight')
